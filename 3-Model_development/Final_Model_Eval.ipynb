# %% [markdown]
# # Model Comparison and Evaluation
# The following notebook will compare the obtained r-squared values from the monthly and daily models.

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create a multi index
arrays = [
    np.array(['Training', 'Training', 'Training', 'Testing', 'Testing', 'Testing']),
    np.array(['MonthlyMean', 'DailyMean', 'DailyMeanMovingAve','MonthlyMean', 'DailyMean', 'DailyMeanMovingAve'])
]

# Summarize r-squared scores
r_squared = {'SO2':[0.7227,0.2640,0.3925,0.4421,0.1606,0.3022],'TRS':[0.5962,0.3027,0.3426,0.2129,0.2701,0.3068],'NO2':[0.5027,0.3418,0.4288,0.6611,0.3130,0.3606],'O3':[0.8857,0.5679,0.6512,0.7381,0.5394,0.6147]}

# Create df
eval = pd.DataFrame(r_squared, index=arrays)


# View df
eval.head(6)
# Out:
#                                 SO2     TRS     NO2      O3
# Training MonthlyMean         0.7227  0.5962  0.5027  0.8857
#          DailyMean           0.2640  0.3027  0.3418  0.5679
#          DailyMeanMovingAve  0.3925  0.3426  0.4288  0.6512
# Testing  MonthlyMean         0.4421  0.2129  0.6611  0.7381
#          DailyMean           0.1606  0.2701  0.3130  0.5394
#          DailyMeanMovingAve  0.3022  0.3068  0.3606  0.6147
